# %% [markdown]
# # Given the iris flower dataset, train a model that distinguishes the different types of iris flower, based on Logistic Regression

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
iris_data = pd.read_csv("./data/IRIS.csv")

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# now i want my X to be the features and Y to be my label

# %%
X = iris_data.drop(columns=["species"])
Y = iris_data["species"]

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
Y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
# prepare model and train it

# %%
model = LogisticRegression()

# %%
# X.values converts it into a NumPy array (ndarray), which is the format that scikit-learn expects internally for numerical computation.
model.fit(X.values, Y)
# you can also do model.fit(X, Y) it is now accepted by sklearn
# Out:
# LogisticRegression()

# %%
# predict

# %%
prediction = model.predict([[9.6,3.5,1.5,0.2]])

# %%
print(prediction)
# Out:
# ['Iris-versicolor']

# %%
# plot

# %%
plt.plot(X.values,Y)

# %%
plt.plot(X['petal_length'],Y)
plt.plot(X['petal_width'],Y)
plt.plot(X['sepal_length'],Y)
plt.plot(X['sepal_width'],Y)

# %%
# Plot 1: Petal Length vs Species
plt.figure(figsize=(8, 4))
plt.scatter(X['petal_length'], Y, color='blue')
plt.xlabel("Petal Length")
plt.ylabel("Species")
plt.title("Petal Length vs Iris Species")
plt.grid(True)
plt.show()

# Plot 2: Petal Width vs Species
plt.figure(figsize=(8, 4))
plt.scatter(X['petal_width'], Y, color='orange')
plt.xlabel("Petal Width")
plt.ylabel("Species")
plt.title("Petal Width vs Iris Species")
plt.grid(True)
plt.show()

# Plot 3: Sepal Length vs Species
plt.figure(figsize=(8, 4))
plt.scatter(X['sepal_length'], Y, color='green')
plt.xlabel("Sepal Length")
plt.ylabel("Species")
plt.title("Sepal Length vs Iris Species")
plt.grid(True)
plt.show()

# Plot 4: Sepal Width vs Species
plt.figure(figsize=(8, 4))
plt.scatter(X['sepal_width'], Y, color='red')
plt.xlabel("Sepal Width")
plt.ylabel("Species")
plt.title("Sepal Width vs Iris Species")
plt.grid(True)
plt.show()
