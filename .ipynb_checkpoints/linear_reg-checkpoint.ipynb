# %% [markdown]
# # Problem Statement

# %% [markdown]
# ## Given a salary dataset with yrs of experience and the corresponding salaries, use an ML model to predict new salary of people based on some different yrs of experience.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("./data/Salary_Data.csv")

# %%
X = ds["YearsExperience"].values
Y = ds["Salary"].values

# %%
X
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
Y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872], dtype=int64)

# %%
plt.plot(X,Y)

# %%
# normalizing the dataset for better rate of convergence
# also, mostly we use numpy arrays:

X = np.array(X)
Y = np.array(Y)

# %%
X
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
# let's normalize : x_new = (x_old - mean)/sd
# where sd = sqrt of variance

# %%
def mean(X):
    return np.sum(X)/len(X)

# %%
def variance(X):
    mean_val = mean(X)
    return (np.sum((X - mean_val)**2)/len(X))

# %%
def norm(X):
    mu = mean(X)
    var = variance(X)
    return (X - mu)/np.sqrt(var)

# %%
X_norm = norm(X)

# %%
X_norm
# Out:
# array([-1.51005294, -1.43837321, -1.36669348, -1.18749416, -1.11581443,
#        -0.86493538, -0.82909552, -0.75741579, -0.75741579, -0.57821647,
#        -0.50653674, -0.47069688, -0.47069688, -0.43485702, -0.29149756,
#        -0.1481381 , -0.07645838, -0.00477865,  0.21026054,  0.2461004 ,
#         0.53281931,  0.6403389 ,  0.92705781,  1.03457741,  1.21377673,
#         1.32129632,  1.50049564,  1.5363355 ,  1.78721455,  1.85889428])

# %%
plt.plot(X_norm, Y)

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(X, Y, label="Original X")
plt.title("Original Scale")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(X_norm, Y, label="Normalized X", color="red")
plt.title("Normalized Scale")
plt.legend()

plt.show()

# %%
# other way of directly calculating
# xnorm = (X - ds["YearsExperience"].mean()) / ds["YearsExperience"].std()
# xnorm """

# %%
import random

# %%
class SimpleLR:
    def __init__(self, learning_rate= 0.1, max_iter= 2000, threshold= 1e-6):
        self.learning_rate = learning_rate
        self.max_iter = max_iter
        self.threshold = threshold
        # for wt and bias, we will use random.uniform

        self.weight = random.uniform(-1,1)
        self.bias = random.uniform(-1,1)

    # now, fit fn that maintains a loss history and tells how the dataset
    # fits the model, also providing the loss history alongside
    # takes in X, Y, and fits the model with X and Y
    def fit(self, X, Y):
        n = len(X)
        loss_history = []
        iter = 0
        least_difference = []
        y_pred = (self.weight)* X + self.bias
        errors = Y - y_pred
        prev_loss = (1/(2*n))*(np.sum((errors)**2))
        loss_history.append(prev_loss)
        for i in range(self.max_iter):
            iter += 1
            w_grad = (1/n) * np.sum(errors * X)
            b_grad = (1/n) * np.sum(errors)

            self.weight += self.learning_rate * w_grad
            self.bias += self.learning_rate * b_grad
            y_pred = (self.weight)* X + self.bias
            errors = Y - y_pred
            curr_loss = (1/(2*n))*(np.sum((errors)**2))
            if(np.abs(curr_loss - prev_loss) < self.threshold):
                least_difference.append(curr_loss - prev_loss)
                break
            else:
                least_difference.append(curr_loss - prev_loss)
                prev_loss = curr_loss
                loss_history.append(prev_loss)
        return loss_history, least_difference, iter
    def letsplot(self, X, Y):
        y_pred = (self.weight)* X + self.bias
        plt.plot(X,Y)
        plt.plot(X, y_pred)

# %%
model = SimpleLR()

# %%
loss_history, least_difference, iter = model.fit(X_norm, Y)

# %%
loss_history
# Out:
# [3251450155.311727,
#  2636645366.2161155,
#  2138653487.0486708,
#  1735280064.9230392,
#  1408547593.0012786,
#  1143894290.7446523,
#  929525115.916785,
#  755886084.3062128,
#  615238468.7016488,
#  501313900.0619524,
#  409034999.463798,
#  334289089.9792931,
#  273744903.296844,
#  224704112.08406034,
#  184981071.20170557,
#  152805408.0869981,
#  126743120.96408522,
#  105632668.39452575,
#  88533201.81318253,
#  74682633.88229449,
#  63463673.858275205,
#  54376316.238819644,
#  47015556.56706056,
#  41053341.232935764,
#  36223946.81229465,
#  32312137.33157535,
#  29143571.65219271,
#  26577033.451892775,
#  24498137.50964984,
#  22814231.796433017,
#  21450268.168727472,
#  20345457.630285922,
#  19450561.0941483,
#  18725694.899876796,
#  18138553.282516897,
#  17662968.57245539,
#  17277744.957305547,
#  16965713.82903417,
#  16712968.615134379,
#  16508244.991875533,
#  16342418.857035859,
#  16208099.687815754,
#  16099301.160747442,
#  16011174.353822112,
#  15939791.640212601,
#  15881971.642188894,
#  15835137.443789693,
#  15797201.743086351,
#  15766473.825516628,
#  15741584.212285165,
#  15721423.625567665,
#  15705093.550326508,
#  15691866.18938116,
#  15681152.027015435,
#  15672473.555499196,
#  15665443.99357104,
#  15659750.048409233,
#  15655137.95282817,
#  15651402.155407505,
#  15648376.159496777,
#  15645925.102809079,
#  15643939.746892042,
#  15642331.608599247,
#  15641029.016582085,
#  15639973.91704818,
#  15639119.286425715,
#  15638427.035621524,
#  15637866.31247013,
#  15637412.126717491,
#  15637044.236257857,
#  15636746.244985556,
#  15636504.872054992,
#  15636309.35998124,
#  15636150.99520149,
#  15636022.7197299,
#  15635918.816597907,
#  15635834.655060992,
#  15635766.484216107,
#  15635711.265831726,
#  15635666.538940394,
#  15635630.310158413,
#  15635600.964845005,
#  15635577.195141142,
#  15635557.94168102,
#  15635542.34637832,
#  15635529.71418313,
#  15635519.482105032,
#  15635511.194121758,
#  15635504.480855322,
#  15635499.043109503,
#  15635494.638535388,
#  15635491.070830358,
#  15635488.180989286,
#  15635485.840217995,
#  15635483.944193276,
#  15635482.408413252,
#  15635481.164431414,
#  15635480.156806145,
#  15635479.340629665,
#  15635478.67952672,
#  15635478.14403333,
#  15635477.710283693,
#  15635477.358946484,
#  15635477.074363343,
#  15635476.843851,
#  15635476.657136,
#  15635476.505896848,
#  15635476.383393148,
#  15635476.284165137,
#  15635476.203790456,
#  15635476.138686953,
#  15635476.08595313,
#  15635476.043238724,
#  15635476.00864005,
#  15635475.980615145,
#  15635475.957914956,
#  -297.9912723004818,
#  -241.3729305639863,
#  -195.512073751539,
#  -158.3647797498852,
#  -128.27547159045935,
#  -103.90313199348748,
#  -84.16153691522777,
#  -68.17084488458931,
#  -55.21838438138366,
#  -44.726891331374645,
#  -36.228781981393695,
#  -29.345313407480717,
#  -23.769703863188624,
#  -19.253460122272372,
#  -15.595302699133754,
#  -12.632195191457868,
#  -10.232078097760677,
#  -8.28798327408731,
#  -6.713266436010599,
#  -5.4377458188682795,
#  -4.404574114829302,
#  -3.5677050296217203,
#  -2.8898410722613335,
#  -2.3407712914049625,
#  -1.8960247188806534,
#  -1.5357800237834454,
#  -1.2439818382263184,
#  -1.0076252687722445,
#  -0.8161764796823263,
#  -0.6611029449850321,
#  -0.535493390634656,
#  -0.4337496366351843,
#  -0.3513372093439102,
#  -0.2845831401646137,
#  -0.2305123433470726,
#  -0.1867149993777275,
#  -0.15123915299773216,
#  -0.12250369973480701,
#  -0.099228011444211,
#  -0.08037468045949936,
#  -0.06510350294411182,
#  -0.05273382365703583,
#  -0.04271440580487251,
#  -0.03459867276251316,
#  -0.028024906292557716,
#  -0.02270018868148327,
#  -0.018387146294116974,
#  -0.014893604442477226,
#  -0.012063795700669289,
#  -0.009771699085831642,
#  -0.007915055379271507,
#  -0.006411207839846611,
#  -0.005193065851926804,
#  -0.0042063891887664795,
#  -0.0034071840345859528,
#  -0.0027598123997449875,
#  -0.0022354479879140854,
#  -0.0018107034265995026,
#  -0.001466682180762291,
#  -0.0011880137026309967,
#  -0.0009622890502214432,
#  -0.0007794462144374847,
#  -0.0006313547492027283,
#  -0.0005114097148180008,
#  -0.0004142243415117264,
#  -0.00033553317189216614,
#  -0.00027177296578884125,
#  -0.0002201516181230545,
#  -0.00017830729484558105,
#  -0.00014442764222621918,
#  -0.0001169983297586441,
#  -9.476393461227417e-05,
#  -7.675588130950928e-05,
#  -6.218068301677704e-05,
#  -5.035661160945892e-05,
#  -4.079192876815796e-05,
#  -3.304146230220795e-05,
#  -2.676062285900116e-05,
#  -2.167932689189911e-05,
#  -1.7564743757247925e-05,
#  -1.4217570424079895e-05,
#  -1.1529773473739624e-05,
#  -9.32253897190094e-06,
#  -7.5660645961761475e-06,
#  -6.118789315223694e-06,
#  -4.9639493227005005e-06,
#  -4.015862941741943e-06,
#  -3.252178430557251e-06,
#  -2.641230821609497e-06,
#  -2.125278115272522e-06,
#  -1.73225998878479e-06,
#  -1.4007091522216797e-06,
#  -1.12876296043396e-06,
#  -9.275972843170166e-07]

# %%
plt.plot(least_difference)

# %%
iter
# Out:
# 163

# %%
# thus instead of max iteration value of 2000, it ran only 163 times
# as it meets the threshold value

# %%
# this will give wrong answer :- model.letsplot(X,Y) 

model.letsplot(X_norm, Y)
